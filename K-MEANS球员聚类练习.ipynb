# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt  
import numpy as np

# %%
data = np.genfromtxt('basketball.txt',delimiter=',')

# %%
def get_loss(centers):
    loss = 0
    for d in data:
        class_kmean = kmeans.predict(d.reshape(1,-1))
        distance = np.sqrt(((d - centers[class_kmean])**2).sum(axis=1))
        loss += distance
    return loss/data.shape[0]

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(data)
centers = kmeans.cluster_centers_

# %%
list_loss = []
for k in range(2,10):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(data)
    centers = kmeans.cluster_centers_
    list_loss.append(get_loss(centers))

# %%
list_loss
# Out:
# [array([ 4.3886988]),
#  array([ 3.76410606]),
#  array([ 3.29455227]),
#  array([ 2.9166162]),
#  array([ 2.68725557]),
#  array([ 2.35718282]),
#  array([ 2.06580568]),
#  array([ 1.81122531])]

# %%
plt.plot(range(2,10),list_loss)
plt.show()

# %%
plt.scatter(data[:,0],data[:,-1])
plt.show()

# %%
data = np.c_[data[:,0],data[:,-1]]

# %%
kmeans = KMeans(n_clusters=3)

# %%
predictions = kmeans.fit_predict(data)

# %%
plt.scatter(data[:,0],data[:,-1],c=predictions)
plt.xlabel('assists_per_minute')
plt.ylabel('points_per_minute')
plt.show()
